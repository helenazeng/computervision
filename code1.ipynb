# %%
# Import MINST data
import tensorflow as tf
import numpy as np
import pylab
import mahotas as mh

# %%
dna = mh.imread('/Users/helenazeng/Documents/EECS442/eecs442challenge/train/color/0.png')
dna = mh.imread('/Users/helenazeng/Documents/EECS442/eecs442challenge/train/color/1.png')

# %%
pylab.imshow(dna)
pylab.show()

# %%
print(type(dna))
print(dna.shape)
# Out:
# <class 'numpy.ndarray'>
# (128, 128, 3)
